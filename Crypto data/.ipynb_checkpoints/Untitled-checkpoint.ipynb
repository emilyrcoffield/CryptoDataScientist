# %%
# %matplotlib notebook
from cryptocmd import CmcScraper
import pandas as pd
import time
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import numpy as np
from datetime import datetime, timedelta

# %%
# scraping data
scraper_bitcoin = CmcScraper("btc")
scraper_eth = CmcScraper("eth")
scraper_xrp = CmcScraper("xrp")
scraper_eos = CmcScraper("eos")
scraper_bch = CmcScraper("bch")
scraper_xlm = CmcScraper("xlm")
scraper_ltc = CmcScraper("ltc")
scraper_ada = CmcScraper("ada")
scraper_xmr = CmcScraper("xmr")
scraper_trx = CmcScraper("trx")


# converting to csv

scraper_bitcoin.export_csv("btc_all_time.csv")
scraper_eth.export_csv("eth_all_time.csv")
scraper_xrp.export_csv("xrp_all_time.csv")
scraper_eos.export_csv("eos_all_time.csv")
scraper_bch.export_csv("bch_all_time.csv")
scraper_xlm.export_csv("xlm_all_time.csv")
scraper_ltc.export_csv("ltc_all_time.csv")
scraper_ada.export_csv("ada_all_time.csv")
scraper_xmr.export_csv("xmr_all_time.csv")
scraper_xmr.export_csv("trx_all_time.csv")

# %%
# place into a dataframe
df_bitcoin = scraper_bitcoin.get_dataframe()
df_etherum = scraper_eth.get_dataframe()
df_xrp = scraper_xrp.get_dataframe()
df_eos = scraper_eos.get_dataframe()
df_bch = scraper_bch.get_dataframe()
df_xlm = scraper_xlm.get_dataframe()
df_ltc = scraper_ltc.get_dataframe()
df_ada = scraper_ada.get_dataframe()
df_xmr = scraper_xmr.get_dataframe()
df_trx = scraper_trx.get_dataframe()
df_etherum
# Out:
#            Date        Open        High         Low       Close      Volume  \
# 0    2018-11-05  207.100000  210.820000  206.570000  209.090000  1613510000
# 1    2018-11-04  200.160000  211.270000  198.990000  207.490000  1749300000
# 2    2018-11-03  200.740000  200.740000  199.530000  200.190000  1307150000
# 3    2018-11-02  198.980000  201.270000  198.750000  200.630000  1451870000
# 4    2018-11-01  197.540000  203.750000  197.330000  198.870000  1336700000
# 5    2018-10-31  197.650000  198.340000  196.530000  197.380000  1442380000
# 6    2018-10-30  197.200000  198.120000  196.350000  197.560000  1363500000
# 7    2018-10-29  205.170000  205.600000  195.730000  197.250000  1517230000
# 8    2018-10-28  204.510000  205.920000  203.520000  205.370000  1139140000
# 9    2018-10-27  203.360000  206.080000  203.130000  204.210000  1084810000
# 10   2018-10-26  202.340000  204.780000  201.550000  203.330000  1161310000
# ...

# %%
df_crypto = pd.DataFrame({"Date": df_bitcoin["Date"],
                          "Bitcoin Cap":df_bitcoin["Market Cap"], 
                          "ETH Cap": df_etherum["Market Cap"],
                          "XRP Cap": df_xrp['Market Cap'],
                          "BCH Cap": df_bch['Market Cap'],
                          "EOS Cap": df_eos['Market Cap'],
                          "XLM Cap": df_xlm['Market Cap'],
                          "LTC Cap": df_ltc['Market Cap'],
                          "ADA Cap": df_ada['Market Cap'],
                          "XMR Cap": df_xmr['Market Cap'],
                          "trx Cap": df_trx['Market Cap'],
                         })

#df_crypto.head(1)
#yesterday= datetime.now() - timedelta(days=1)
#yesterday.strftime('%m%d%y')
#date = [yesterday for i in range(0, len(df_crypto["Bitcoin Cap"]))]
#df_crypto["yesterday"] = date

# %%
#df_crypto_max = df_crypto.max(axis=1)
#df_crypto["Max"] = df_crypto_max
#df_crypto
#gapminder_ocean.drop(['pop'], axis=1)

most_update = df_crypto.loc[0]
most_update.drop(["date"])
#most_update.remove("Date")
most_update
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-26949ebea7cb> in <module>()
#       5
#       6 most_update = df_crypto.loc[0]
# ----> 7 most_update.drop(["date"])
#       8 #most_update.remove("Date")
#       9 most_update
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3414         return super(Series, self).drop(labels=labels, axis=axis, index=index,
#    3415                                         columns=columns, level=level,
# -> 3416                                         inplace=inplace, errors=errors)
#    3417
#    3418     @Substitution(**_shared_doc_kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
# ...

# %%
x_axis = np.arange(len(df_crypto.columns))
plt.bar(x_axis, df_crypto.loc[0], color='r', alpha=0.5, align="center")
plt.xlim(-0.75, len(x_axis)+1)
# Out:
# <div id='826a17dc-8f87-4036-be71-7b05bd95fd14'></div>
# (-0.75, 11)

# %%
tick_locations = [ value for value in x_axis]
plt.xticks(tick_locations, ["Bitcoin Cap","ETH Cap", "XRP Cap", "BCH Cap", "EOS Cap", "XLM Cap", "LTC Cap","ADA Cap", "XMR Cap", "trx Cap"])
# Out:
# ([<matplotlib.axis.XTick at 0x98de910>,
# ...
#  <a list of 10 Text xticklabel objects>)

# %%
fig, (ax1, ax2) = plt.subplots(2,1)
ax1.set_ylabel('Close ($)',fontsize=12)
ax2.set_ylabel('Volume ($ bn)',fontsize=12)
ax1.plot(df_bch['Date'].astype(datetime.datetime),df_bch['Open'])
ax2.bar(df_bch['Date'].astype(datetime.datetime).values, df_bch['Volume'].values)
plt.show
# Out:
# <div id='cd31f984-30aa-4a02-ba70-2fde6ce72e67'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-197a2dc798fe> in <module>()
#       2 ax1.set_ylabel('Close ($)',fontsize=12)
#       3 ax2.set_ylabel('Volume ($ bn)',fontsize=12)
# ----> 4 ax1.plot(df_bch['Date'].astype(datetime.datetime),df_bch['Open'])
#       5 ax2.bar(df_bch['Date'].astype(datetime.datetime).values, df_bch['Volume'].values)
#       6 plt.show
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'
